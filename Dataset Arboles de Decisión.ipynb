# %% [markdown]
# **Arboles de Desición**

# %%
#Importamos las librerias
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score

# %%
#Cargamos el dataset y mostramos las 5 primeras filas
data = pd.read_csv("winequality-red.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.hist(data.quality)
# Out:
# (array([ 10.,   0.,  53.,   0., 681.,   0., 638.,   0., 199.,  18.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(x = "fixed acidity", y = "volatile acidity", hue = "citric acid", data = data)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='volatile acidity'>

# %%
predictors_col = ["fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides",	"free sulfur dioxide", "total sulfur dioxide", "density", "pH",	"sulphates", "alcohol"]	
target_col = ['quality']

# %%
predictors = data[predictors_col]
target = data[target_col]

# %%
predictors
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
corr = predictors.corr()
corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# ...

# %%
sns.heatmap(corr)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.6, random_state=13)

# %%
tree = DecisionTreeClassifier()

# %%
arbol = tree.fit(X_train, y_train)

# %%
plot_tree(arbol)
# Out:
# [Text(0.4789794921875, 0.9761904761904762, 'x[10] <= 10.35\ngini = 0.646\nsamples = 639\nvalue = [4, 23, 270, 254, 80, 8]'),
#  Text(0.22734375, 0.9285714285714286, 'x[9] <= 0.555\ngini = 0.538\nsamples = 341\nvalue = [2, 16, 206, 104, 13, 0]'),
#  Text(0.06953125, 0.8809523809523809, 'x[4] <= 0.069\ngini = 0.372\nsamples = 130\nvalue = [1, 9, 101, 18, 1, 0]'),
#  Text(0.0296875, 0.8333333333333334, 'x[9] <= 0.475\ngini = 0.658\nsamples = 21\nvalue = [1, 2, 9, 8, 1, 0]'),
#  Text(0.0125, 0.7857142857142857, 'x[3] <= 1.3\ngini = 0.406\nsamples = 8\nvalue = [0, 0, 6, 1, 1, 0]'),
#  Text(0.00625, 0.7380952380952381, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.01875, 0.7380952380952381, 'x[7] <= 0.998\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.0125, 0.6904761904761905, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.025, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
# ...

# %%
predicciones = arbol.predict(X_test)

# %%
predicciones
# Out:
# array([8, 5, 5, 5, 7, 5, 6, 7, 6, 5, 5, 5, 5, 6, 7, 4, 7, 7, 5, 7, 5, 6,
#        6, 5, 7, 5, 5, 5, 4, 6, 6, 6, 5, 6, 4, 7, 6, 5, 6, 5, 6, 5, 6, 6,
#        5, 6, 6, 8, 7, 6, 5, 5, 6, 5, 7, 5, 5, 6, 7, 5, 5, 5, 5, 5, 6, 7,
#        6, 6, 5, 6, 6, 5, 6, 6, 5, 5, 5, 6, 5, 5, 8, 7, 6, 5, 6, 5, 6, 5,
#        6, 5, 6, 6, 6, 7, 6, 6, 6, 5, 5, 7, 5, 7, 5, 5, 8, 6, 5, 6, 5, 7,
#        4, 8, 6, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6, 5, 5, 5, 5, 6, 7, 6, 5,
#        5, 6, 6, 5, 7, 5, 6, 5, 5, 5, 5, 6, 7, 3, 6, 5, 6, 6, 5, 6, 5, 5,
#        6, 5, 5, 5, 6, 5, 6, 5, 6, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 5, 7, 5,
#        5, 5, 5, 5, 6, 6, 6, 6, 5, 5, 6, 6, 5, 5, 5, 5, 5, 5, 6, 5, 6, 7,
#        6, 5, 7, 6, 5, 6, 6, 7, 6, 5, 5, 6, 6, 5, 5, 6, 8, 5, 5, 7, 6, 7,
#        5, 5, 5, 6, 5, 6, 5, 6, 4, 7, 6, 5, 5, 5, 5, 5, 6, 5, 6, 4, 8, 6,
#        5, 5, 5, 6, 6, 5, 5, 6, 6, 5, 5, 6, 7, 6, 5, 6, 5, 6, 5, 6, 7, 5,
#        5, 5, 6, 7, 5, 5, 6, 5, 5, 5, 6, 5, 6, 6, 5, 6, 5, 6, 5, 5, 7, 4,
# ...

# %%
pd.crosstab(np.array([y[0] for y in y_test.values.tolist()]), predicciones, rownames=['actual'], colnames=['predicciones'])
# Out:
# predicciones  3   4    5    6   7  8
# actual
# 3             0   1    1    3   1  0
# 4             1   5   12    9   3  0
# 5             7  21  284   84  13  2
# 6             2   4  124  197  49  8
# 7             0   1   14   50  50  4
# 8             0   1    0    4   4  1

# %%
accuracy = accuracy_score(y_test,predicciones)
accuracy
# Out:
# 0.559375
